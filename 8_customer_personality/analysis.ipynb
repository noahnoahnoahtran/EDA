# %% [markdown]
# # **1. Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering
from yellowbrick.cluster import KElbowVisualizer

import warnings
warnings.filterwarnings("ignore")
# Out:
# c:\Users\ACER\ANA\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # **2. Load dataset**

# %%
data = pd.read_csv("./datasets/marketing_campaign.csv", sep="\t")

# %% [markdown]
# # **3. Basic exploration**

# %%
print(f"Shape of the dataset: {data.shape}")
print(f"\nGlimpse of the dataset:")
data.head().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Shape of the dataset: (2240, 29)
#
# Glimpse of the dataset:
# <style type="text/css">
# #T_c3b49_row0_col0, #T_c3b49_row0_col1, #T_c3b49_row0_col2, #T_c3b49_row0_col3, #T_c3b49_row0_col4, #T_c3b49_row0_col5, #T_c3b49_row0_col6, #T_c3b49_row0_col7, #T_c3b49_row0_col8, #T_c3b49_row0_col9, #T_c3b49_row0_col10, #T_c3b49_row0_col11, #T_c3b49_row0_col12, #T_c3b49_row0_col13, #T_c3b49_row0_col14, #T_c3b49_row0_col15, #T_c3b49_row0_col16, #T_c3b49_row0_col17, #T_c3b49_row0_col18, #T_c3b49_row0_col19, #T_c3b49_row0_col20, #T_c3b49_row0_col21, #T_c3b49_row0_col22, #T_c3b49_row0_col23, #T_c3b49_row0_col24, #T_c3b49_row0_col25, #T_c3b49_row0_col26, #T_c3b49_row0_col27, #T_c3b49_row0_col28, #T_c3b49_row1_col0, #T_c3b49_row1_col1, #T_c3b49_row1_col2, #T_c3b49_row1_col3, #T_c3b49_row1_col4, #T_c3b49_row1_col5, #T_c3b49_row1_col6, #T_c3b49_row1_col7, #T_c3b49_row1_col8, #T_c3b49_row1_col9, #T_c3b49_row1_col10, #T_c3b49_row1_col11, #T_c3b49_row1_col12, #T_c3b49_row1_col13, #T_c3b49_row1_col14, #T_c3b49_row1_col15, #T_c3b49_row1_col16, #T_c3b49_row1_col17, #T_c3b49_row1_col18, #T_c3b49_row1_col19, #T_c3b49_row1_col20, #T_c3b49_row1_col21, #T_c3b49_row1_col22, #T_c3b49_row1_col23, #T_c3b49_row1_col24, #T_c3b49_row1_col25, #T_c3b49_row1_col26, #T_c3b49_row1_col27, #T_c3b49_row1_col28, #T_c3b49_row2_col0, #T_c3b49_row2_col1, #T_c3b49_row2_col2, #T_c3b49_row2_col3, #T_c3b49_row2_col4, #T_c3b49_row2_col5, #T_c3b49_row2_col6, #T_c3b49_row2_col7, #T_c3b49_row2_col8, #T_c3b49_row2_col9, #T_c3b49_row2_col10, #T_c3b49_row2_col11, #T_c3b49_row2_col12, #T_c3b49_row2_col13, #T_c3b49_row2_col14, #T_c3b49_row2_col15, #T_c3b49_row2_col16, #T_c3b49_row2_col17, #T_c3b49_row2_col18, #T_c3b49_row2_col19, #T_c3b49_row2_col20, #T_c3b49_row2_col21, #T_c3b49_row2_col22, #T_c3b49_row2_col23, #T_c3b49_row2_col24, #T_c3b49_row2_col25, #T_c3b49_row2_col26, #T_c3b49_row2_col27, #T_c3b49_row2_col28, #T_c3b49_row3_col0, #T_c3b49_row3_col1, #T_c3b49_row3_col2, #T_c3b49_row3_col3, #T_c3b49_row3_col4, #T_c3b49_row3_col5, #T_c3b49_row3_col6, #T_c3b49_row3_col7, #T_c3b49_row3_col8, #T_c3b49_row3_col9, #T_c3b49_row3_col10, #T_c3b49_row3_col11, #T_c3b49_row3_col12, #T_c3b49_row3_col13, #T_c3b49_row3_col14, #T_c3b49_row3_col15, #T_c3b49_row3_col16, #T_c3b49_row3_col17, #T_c3b49_row3_col18, #T_c3b49_row3_col19, #T_c3b49_row3_col20, #T_c3b49_row3_col21, #T_c3b49_row3_col22, #T_c3b49_row3_col23, #T_c3b49_row3_col24, #T_c3b49_row3_col25, #T_c3b49_row3_col26, #T_c3b49_row3_col27, #T_c3b49_row3_col28, #T_c3b49_row4_col0, #T_c3b49_row4_col1, #T_c3b49_row4_col2, #T_c3b49_row4_col3, #T_c3b49_row4_col4, #T_c3b49_row4_col5, #T_c3b49_row4_col6, #T_c3b49_row4_col7, #T_c3b49_row4_col8, #T_c3b49_row4_col9, #T_c3b49_row4_col10, #T_c3b49_row4_col11, #T_c3b49_row4_col12, #T_c3b49_row4_col13, #T_c3b49_row4_col14, #T_c3b49_row4_col15, #T_c3b49_row4_col16, #T_c3b49_row4_col17, #T_c3b49_row4_col18, #T_c3b49_row4_col19, #T_c3b49_row4_col20, #T_c3b49_row4_col21, #T_c3b49_row4_col22, #T_c3b49_row4_col23, #T_c3b49_row4_col24, #T_c3b49_row4_col25, #T_c3b49_row4_col26, #T_c3b49_row4_col27, #T_c3b49_row4_col28 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_c3b49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3b49_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_c3b49_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_c3b49_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_c3b49_level0_col3" class="col_heading level0 col3" >Marital_Status</th>
#       <th id="T_c3b49_level0_col4" class="col_heading level0 col4" >Income</th>
#       <th id="T_c3b49_level0_col5" class="col_heading level0 col5" >Kidhome</th>
#       <th id="T_c3b49_level0_col6" class="col_heading level0 col6" >Teenhome</th>
#       <th id="T_c3b49_level0_col7" class="col_heading level0 col7" >Dt_Customer</th>
#       <th id="T_c3b49_level0_col8" class="col_heading level0 col8" >Recency</th>
#       <th id="T_c3b49_level0_col9" class="col_heading level0 col9" >MntWines</th>
#       <th id="T_c3b49_level0_col10" class="col_heading level0 col10" >MntFruits</th>
#       <th id="T_c3b49_level0_col11" class="col_heading level0 col11" >MntMeatProducts</th>
#       <th id="T_c3b49_level0_col12" class="col_heading level0 col12" >MntFishProducts</th>
#       <th id="T_c3b49_level0_col13" class="col_heading level0 col13" >MntSweetProducts</th>
#       <th id="T_c3b49_level0_col14" class="col_heading level0 col14" >MntGoldProds</th>
#       <th id="T_c3b49_level0_col15" class="col_heading level0 col15" >NumDealsPurchases</th>
#       <th id="T_c3b49_level0_col16" class="col_heading level0 col16" >NumWebPurchases</th>
#       <th id="T_c3b49_level0_col17" class="col_heading level0 col17" >NumCatalogPurchases</th>
#       <th id="T_c3b49_level0_col18" class="col_heading level0 col18" >NumStorePurchases</th>
#       <th id="T_c3b49_level0_col19" class="col_heading level0 col19" >NumWebVisitsMonth</th>
#       <th id="T_c3b49_level0_col20" class="col_heading level0 col20" >AcceptedCmp3</th>
#       <th id="T_c3b49_level0_col21" class="col_heading level0 col21" >AcceptedCmp4</th>
#       <th id="T_c3b49_level0_col22" class="col_heading level0 col22" >AcceptedCmp5</th>
#       <th id="T_c3b49_level0_col23" class="col_heading level0 col23" >AcceptedCmp1</th>
#       <th id="T_c3b49_level0_col24" class="col_heading level0 col24" >AcceptedCmp2</th>
#       <th id="T_c3b49_level0_col25" class="col_heading level0 col25" >Complain</th>
#       <th id="T_c3b49_level0_col26" class="col_heading level0 col26" >Z_CostContact</th>
#       <th id="T_c3b49_level0_col27" class="col_heading level0 col27" >Z_Revenue</th>
#       <th id="T_c3b49_level0_col28" class="col_heading level0 col28" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3b49_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3b49_row0_col0" class="data row0 col0" >5524</td>
#       <td id="T_c3b49_row0_col1" class="data row0 col1" >1957</td>
#       <td id="T_c3b49_row0_col2" class="data row0 col2" >Graduation</td>
#       <td id="T_c3b49_row0_col3" class="data row0 col3" >Single</td>
#       <td id="T_c3b49_row0_col4" class="data row0 col4" >58138.000000</td>
#       <td id="T_c3b49_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_c3b49_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_c3b49_row0_col7" class="data row0 col7" >04-09-2012</td>
#       <td id="T_c3b49_row0_col8" class="data row0 col8" >58</td>
#       <td id="T_c3b49_row0_col9" class="data row0 col9" >635</td>
#       <td id="T_c3b49_row0_col10" class="data row0 col10" >88</td>
#       <td id="T_c3b49_row0_col11" class="data row0 col11" >546</td>
#       <td id="T_c3b49_row0_col12" class="data row0 col12" >172</td>
#       <td id="T_c3b49_row0_col13" class="data row0 col13" >88</td>
#       <td id="T_c3b49_row0_col14" class="data row0 col14" >88</td>
#       <td id="T_c3b49_row0_col15" class="data row0 col15" >3</td>
#       <td id="T_c3b49_row0_col16" class="data row0 col16" >8</td>
#       <td id="T_c3b49_row0_col17" class="data row0 col17" >10</td>
#       <td id="T_c3b49_row0_col18" class="data row0 col18" >4</td>
#       <td id="T_c3b49_row0_col19" class="data row0 col19" >7</td>
#       <td id="T_c3b49_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_c3b49_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_c3b49_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_c3b49_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_c3b49_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_c3b49_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_c3b49_row0_col26" class="data row0 col26" >3</td>
#       <td id="T_c3b49_row0_col27" class="data row0 col27" >11</td>
#       <td id="T_c3b49_row0_col28" class="data row0 col28" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c3b49_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3b49_row1_col0" class="data row1 col0" >2174</td>
#       <td id="T_c3b49_row1_col1" class="data row1 col1" >1954</td>

# %%
print(f"Information of the dataset:\n")
print(data.info())
# Out:
# Information of the dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  AcceptedCmp3         2240 non-null   int64
#  21  AcceptedCmp4         2240 non-null   int64
#  22  AcceptedCmp5         2240 non-null   int64
#  23  AcceptedCmp1         2240 non-null   int64
#  24  AcceptedCmp2         2240 non-null   int64
#  25  Complain             2240 non-null   int64
#  26  Z_CostContact        2240 non-null   int64
#  27  Z_Revenue            2240 non-null   int64
#  28  Response             2240 non-null   int64
# dtypes: float64(1), int64(25), object(3)
# memory usage: 507.6+ KB
# None

# %%
print(f"Summary of the dataset:")
data.describe().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Summary of the dataset:
# <style type="text/css">
# #T_ee5ac_row0_col0, #T_ee5ac_row0_col1, #T_ee5ac_row0_col2, #T_ee5ac_row0_col3, #T_ee5ac_row0_col4, #T_ee5ac_row0_col5, #T_ee5ac_row0_col6, #T_ee5ac_row0_col7, #T_ee5ac_row0_col8, #T_ee5ac_row0_col9, #T_ee5ac_row0_col10, #T_ee5ac_row0_col11, #T_ee5ac_row0_col12, #T_ee5ac_row0_col13, #T_ee5ac_row0_col14, #T_ee5ac_row0_col15, #T_ee5ac_row0_col16, #T_ee5ac_row0_col17, #T_ee5ac_row0_col18, #T_ee5ac_row0_col19, #T_ee5ac_row0_col20, #T_ee5ac_row0_col21, #T_ee5ac_row0_col22, #T_ee5ac_row0_col23, #T_ee5ac_row0_col24, #T_ee5ac_row0_col25, #T_ee5ac_row1_col0, #T_ee5ac_row1_col1, #T_ee5ac_row1_col2, #T_ee5ac_row1_col3, #T_ee5ac_row1_col4, #T_ee5ac_row1_col5, #T_ee5ac_row1_col6, #T_ee5ac_row1_col7, #T_ee5ac_row1_col8, #T_ee5ac_row1_col9, #T_ee5ac_row1_col10, #T_ee5ac_row1_col11, #T_ee5ac_row1_col12, #T_ee5ac_row1_col13, #T_ee5ac_row1_col14, #T_ee5ac_row1_col15, #T_ee5ac_row1_col16, #T_ee5ac_row1_col17, #T_ee5ac_row1_col18, #T_ee5ac_row1_col19, #T_ee5ac_row1_col20, #T_ee5ac_row1_col21, #T_ee5ac_row1_col22, #T_ee5ac_row1_col23, #T_ee5ac_row1_col24, #T_ee5ac_row1_col25, #T_ee5ac_row2_col0, #T_ee5ac_row2_col1, #T_ee5ac_row2_col2, #T_ee5ac_row2_col3, #T_ee5ac_row2_col4, #T_ee5ac_row2_col5, #T_ee5ac_row2_col6, #T_ee5ac_row2_col7, #T_ee5ac_row2_col8, #T_ee5ac_row2_col9, #T_ee5ac_row2_col10, #T_ee5ac_row2_col11, #T_ee5ac_row2_col12, #T_ee5ac_row2_col13, #T_ee5ac_row2_col14, #T_ee5ac_row2_col15, #T_ee5ac_row2_col16, #T_ee5ac_row2_col17, #T_ee5ac_row2_col18, #T_ee5ac_row2_col19, #T_ee5ac_row2_col20, #T_ee5ac_row2_col21, #T_ee5ac_row2_col22, #T_ee5ac_row2_col23, #T_ee5ac_row2_col24, #T_ee5ac_row2_col25, #T_ee5ac_row3_col0, #T_ee5ac_row3_col1, #T_ee5ac_row3_col2, #T_ee5ac_row3_col3, #T_ee5ac_row3_col4, #T_ee5ac_row3_col5, #T_ee5ac_row3_col6, #T_ee5ac_row3_col7, #T_ee5ac_row3_col8, #T_ee5ac_row3_col9, #T_ee5ac_row3_col10, #T_ee5ac_row3_col11, #T_ee5ac_row3_col12, #T_ee5ac_row3_col13, #T_ee5ac_row3_col14, #T_ee5ac_row3_col15, #T_ee5ac_row3_col16, #T_ee5ac_row3_col17, #T_ee5ac_row3_col18, #T_ee5ac_row3_col19, #T_ee5ac_row3_col20, #T_ee5ac_row3_col21, #T_ee5ac_row3_col22, #T_ee5ac_row3_col23, #T_ee5ac_row3_col24, #T_ee5ac_row3_col25, #T_ee5ac_row4_col0, #T_ee5ac_row4_col1, #T_ee5ac_row4_col2, #T_ee5ac_row4_col3, #T_ee5ac_row4_col4, #T_ee5ac_row4_col5, #T_ee5ac_row4_col6, #T_ee5ac_row4_col7, #T_ee5ac_row4_col8, #T_ee5ac_row4_col9, #T_ee5ac_row4_col10, #T_ee5ac_row4_col11, #T_ee5ac_row4_col12, #T_ee5ac_row4_col13, #T_ee5ac_row4_col14, #T_ee5ac_row4_col15, #T_ee5ac_row4_col16, #T_ee5ac_row4_col17, #T_ee5ac_row4_col18, #T_ee5ac_row4_col19, #T_ee5ac_row4_col20, #T_ee5ac_row4_col21, #T_ee5ac_row4_col22, #T_ee5ac_row4_col23, #T_ee5ac_row4_col24, #T_ee5ac_row4_col25, #T_ee5ac_row5_col0, #T_ee5ac_row5_col1, #T_ee5ac_row5_col2, #T_ee5ac_row5_col3, #T_ee5ac_row5_col4, #T_ee5ac_row5_col5, #T_ee5ac_row5_col6, #T_ee5ac_row5_col7, #T_ee5ac_row5_col8, #T_ee5ac_row5_col9, #T_ee5ac_row5_col10, #T_ee5ac_row5_col11, #T_ee5ac_row5_col12, #T_ee5ac_row5_col13, #T_ee5ac_row5_col14, #T_ee5ac_row5_col15, #T_ee5ac_row5_col16, #T_ee5ac_row5_col17, #T_ee5ac_row5_col18, #T_ee5ac_row5_col19, #T_ee5ac_row5_col20, #T_ee5ac_row5_col21, #T_ee5ac_row5_col22, #T_ee5ac_row5_col23, #T_ee5ac_row5_col24, #T_ee5ac_row5_col25, #T_ee5ac_row6_col0, #T_ee5ac_row6_col1, #T_ee5ac_row6_col2, #T_ee5ac_row6_col3, #T_ee5ac_row6_col4, #T_ee5ac_row6_col5, #T_ee5ac_row6_col6, #T_ee5ac_row6_col7, #T_ee5ac_row6_col8, #T_ee5ac_row6_col9, #T_ee5ac_row6_col10, #T_ee5ac_row6_col11, #T_ee5ac_row6_col12, #T_ee5ac_row6_col13, #T_ee5ac_row6_col14, #T_ee5ac_row6_col15, #T_ee5ac_row6_col16, #T_ee5ac_row6_col17, #T_ee5ac_row6_col18, #T_ee5ac_row6_col19, #T_ee5ac_row6_col20, #T_ee5ac_row6_col21, #T_ee5ac_row6_col22, #T_ee5ac_row6_col23, #T_ee5ac_row6_col24, #T_ee5ac_row6_col25, #T_ee5ac_row7_col0, #T_ee5ac_row7_col1, #T_ee5ac_row7_col2, #T_ee5ac_row7_col3, #T_ee5ac_row7_col4, #T_ee5ac_row7_col5, #T_ee5ac_row7_col6, #T_ee5ac_row7_col7, #T_ee5ac_row7_col8, #T_ee5ac_row7_col9, #T_ee5ac_row7_col10, #T_ee5ac_row7_col11, #T_ee5 ...
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_ee5ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee5ac_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_ee5ac_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_ee5ac_level0_col2" class="col_heading level0 col2" >Income</th>
#       <th id="T_ee5ac_level0_col3" class="col_heading level0 col3" >Kidhome</th>
#       <th id="T_ee5ac_level0_col4" class="col_heading level0 col4" >Teenhome</th>
#       <th id="T_ee5ac_level0_col5" class="col_heading level0 col5" >Recency</th>
#       <th id="T_ee5ac_level0_col6" class="col_heading level0 col6" >MntWines</th>
#       <th id="T_ee5ac_level0_col7" class="col_heading level0 col7" >MntFruits</th>
#       <th id="T_ee5ac_level0_col8" class="col_heading level0 col8" >MntMeatProducts</th>
#       <th id="T_ee5ac_level0_col9" class="col_heading level0 col9" >MntFishProducts</th>
#       <th id="T_ee5ac_level0_col10" class="col_heading level0 col10" >MntSweetProducts</th>
#       <th id="T_ee5ac_level0_col11" class="col_heading level0 col11" >MntGoldProds</th>
#       <th id="T_ee5ac_level0_col12" class="col_heading level0 col12" >NumDealsPurchases</th>
#       <th id="T_ee5ac_level0_col13" class="col_heading level0 col13" >NumWebPurchases</th>
#       <th id="T_ee5ac_level0_col14" class="col_heading level0 col14" >NumCatalogPurchases</th>
#       <th id="T_ee5ac_level0_col15" class="col_heading level0 col15" >NumStorePurchases</th>
#       <th id="T_ee5ac_level0_col16" class="col_heading level0 col16" >NumWebVisitsMonth</th>
#       <th id="T_ee5ac_level0_col17" class="col_heading level0 col17" >AcceptedCmp3</th>
#       <th id="T_ee5ac_level0_col18" class="col_heading level0 col18" >AcceptedCmp4</th>
#       <th id="T_ee5ac_level0_col19" class="col_heading level0 col19" >AcceptedCmp5</th>
#       <th id="T_ee5ac_level0_col20" class="col_heading level0 col20" >AcceptedCmp1</th>
#       <th id="T_ee5ac_level0_col21" class="col_heading level0 col21" >AcceptedCmp2</th>
#       <th id="T_ee5ac_level0_col22" class="col_heading level0 col22" >Complain</th>
#       <th id="T_ee5ac_level0_col23" class="col_heading level0 col23" >Z_CostContact</th>
#       <th id="T_ee5ac_level0_col24" class="col_heading level0 col24" >Z_Revenue</th>
#       <th id="T_ee5ac_level0_col25" class="col_heading level0 col25" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee5ac_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_ee5ac_row0_col0" class="data row0 col0" >2240.000000</td>
#       <td id="T_ee5ac_row0_col1" class="data row0 col1" >2240.000000</td>
#       <td id="T_ee5ac_row0_col2" class="data row0 col2" >2216.000000</td>
#       <td id="T_ee5ac_row0_col3" class="data row0 col3" >2240.000000</td>
#       <td id="T_ee5ac_row0_col4" class="data row0 col4" >2240.000000</td>
#       <td id="T_ee5ac_row0_col5" class="data row0 col5" >2240.000000</td>
#       <td id="T_ee5ac_row0_col6" class="data row0 col6" >2240.000000</td>
#       <td id="T_ee5ac_row0_col7" class="data row0 col7" >2240.000000</td>
#       <td id="T_ee5ac_row0_col8" class="data row0 col8" >2240.000000</td>
#       <td id="T_ee5ac_row0_col9" class="data row0 col9" >2240.000000</td>
#       <td id="T_ee5ac_row0_col10" class="data row0 col10" >2240.000000</td>
#       <td id="T_ee5ac_row0_col11" class="data row0 col11" >2240.000000</td>
#       <td id="T_ee5ac_row0_col12" class="data row0 col12" >2240.000000</td>
#       <td id="T_ee5ac_row0_col13" class="data row0 col13" >2240.000000</td>
#       <td id="T_ee5ac_row0_col14" class="data row0 col14" >2240.000000</td>
#       <td id="T_ee5ac_r

# %%
data.describe(include=object).T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_e2d24_row0_col0, #T_e2d24_row0_col1, #T_e2d24_row0_col2, #T_e2d24_row0_col3, #T_e2d24_row1_col0, #T_e2d24_row1_col1, #T_e2d24_row1_col2, #T_e2d24_row1_col3, #T_e2d24_row2_col0, #T_e2d24_row2_col1, #T_e2d24_row2_col2, #T_e2d24_row2_col3 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_e2d24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2d24_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_e2d24_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_e2d24_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_e2d24_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2d24_level0_row0" class="row_heading level0 row0" >Education</th>
#       <td id="T_e2d24_row0_col0" class="data row0 col0" >2240</td>
#       <td id="T_e2d24_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_e2d24_row0_col2" class="data row0 col2" >Graduation</td>
#       <td id="T_e2d24_row0_col3" class="data row0 col3" >1127</td>
#     </tr>
#     <tr>
#       <th id="T_e2d24_level0_row1" class="row_heading level0 row1" >Marital_Status</th>
#       <td id="T_e2d24_row1_col0" class="data row1 col0" >2240</td>
#       <td id="T_e2d24_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_e2d24_row1_col2" class="data row1 col2" >Married</td>
#       <td id="T_e2d24_row1_col3" class="data row1 col3" >864</td>
#     </tr>
#     <tr>
#       <th id="T_e2d24_level0_row2" class="row_heading level0 row2" >Dt_Customer</th>
#       <td id="T_e2d24_row2_col0" class="data row2 col0" >2240</td>
#       <td id="T_e2d24_row2_col1" class="data row2 col1" >663</td>
#       <td id="T_e2d24_row2_col2" class="data row2 col2" >31-08-2012</td>
#       <td id="T_e2d24_row2_col3" class="data row2 col3" >12</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f"Null values of the dataset:")
data.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Null values of the dataset:
# <style type="text/css">
# #T_c6b24_row0_col0, #T_c6b24_row0_col1, #T_c6b24_row0_col2, #T_c6b24_row0_col3, #T_c6b24_row0_col4, #T_c6b24_row0_col5, #T_c6b24_row0_col6, #T_c6b24_row0_col7, #T_c6b24_row0_col8, #T_c6b24_row0_col9, #T_c6b24_row0_col10, #T_c6b24_row0_col11, #T_c6b24_row0_col12, #T_c6b24_row0_col13, #T_c6b24_row0_col14, #T_c6b24_row0_col15, #T_c6b24_row0_col16, #T_c6b24_row0_col17, #T_c6b24_row0_col18, #T_c6b24_row0_col19, #T_c6b24_row0_col20, #T_c6b24_row0_col21, #T_c6b24_row0_col22, #T_c6b24_row0_col23, #T_c6b24_row0_col24, #T_c6b24_row0_col25, #T_c6b24_row0_col26, #T_c6b24_row0_col27, #T_c6b24_row0_col28 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_c6b24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6b24_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_c6b24_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_c6b24_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_c6b24_level0_col3" class="col_heading level0 col3" >Marital_Status</th>
#       <th id="T_c6b24_level0_col4" class="col_heading level0 col4" >Income</th>
#       <th id="T_c6b24_level0_col5" class="col_heading level0 col5" >Kidhome</th>
#       <th id="T_c6b24_level0_col6" class="col_heading level0 col6" >Teenhome</th>
#       <th id="T_c6b24_level0_col7" class="col_heading level0 col7" >Dt_Customer</th>
#       <th id="T_c6b24_level0_col8" class="col_heading level0 col8" >Recency</th>
#       <th id="T_c6b24_level0_col9" class="col_heading level0 col9" >MntWines</th>
#       <th id="T_c6b24_level0_col10" class="col_heading level0 col10" >MntFruits</th>
#       <th id="T_c6b24_level0_col11" class="col_heading level0 col11" >MntMeatProducts</th>
#       <th id="T_c6b24_level0_col12" class="col_heading level0 col12" >MntFishProducts</th>
#       <th id="T_c6b24_level0_col13" class="col_heading level0 col13" >MntSweetProducts</th>
#       <th id="T_c6b24_level0_col14" class="col_heading level0 col14" >MntGoldProds</th>
#       <th id="T_c6b24_level0_col15" class="col_heading level0 col15" >NumDealsPurchases</th>
#       <th id="T_c6b24_level0_col16" class="col_heading level0 col16" >NumWebPurchases</th>
#       <th id="T_c6b24_level0_col17" class="col_heading level0 col17" >NumCatalogPurchases</th>
#       <th id="T_c6b24_level0_col18" class="col_heading level0 col18" >NumStorePurchases</th>
#       <th id="T_c6b24_level0_col19" class="col_heading level0 col19" >NumWebVisitsMonth</th>
#       <th id="T_c6b24_level0_col20" class="col_heading level0 col20" >AcceptedCmp3</th>
#       <th id="T_c6b24_level0_col21" class="col_heading level0 col21" >AcceptedCmp4</th>
#       <th id="T_c6b24_level0_col22" class="col_heading level0 col22" >AcceptedCmp5</th>
#       <th id="T_c6b24_level0_col23" class="col_heading level0 col23" >AcceptedCmp1</th>
#       <th id="T_c6b24_level0_col24" class="col_heading level0 col24" >AcceptedCmp2</th>
#       <th id="T_c6b24_level0_col25" class="col_heading level0 col25" >Complain</th>
#       <th id="T_c6b24_level0_col26" class="col_heading level0 col26" >Z_CostContact</th>
#       <th id="T_c6b24_level0_col27" class="col_heading level0 col27" >Z_Revenue</th>
#       <th id="T_c6b24_level0_col28" class="col_heading level0 col28" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6b24_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6b24_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c6b24_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_c6b24_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_c6b24_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c6b24_row0_col4" class="data row0 col4" >24</td>
#       <td id="T_c6b24_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_c6b24_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_c6b24_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_c6b24_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_c6b24_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_c6b24_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_c6b24_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_c6b24_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_c6b24_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_c6b24_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_c6b24_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_c6b24_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_c6b24_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_c6b24_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_c6b24_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_c6b24_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_c6b24_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_c6b24_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_c6b24_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_c6b24_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_c6b24_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_c6b24_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_c6b24_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_c6b24_row0_col28" class="data row0 col28" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Insights**:
# - There are missing values in Income. The rows with missing income values will be dropped.
# - Dt_Customer that indicates the date a customer joined is not parsed as DateTime.

# %%
data.dropna(axis=0, inplace=True)
print(f"After dropping null values, the shape of the dataset is {data.shape}")
print(f"After dropping null values, null values of the dataset:")
data.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After dropping null values, the shape of the dataset is (2216, 29)
# After dropping null values, null values of the dataset:
# <style type="text/css">
# #T_8da40_row0_col0, #T_8da40_row0_col1, #T_8da40_row0_col2, #T_8da40_row0_col3, #T_8da40_row0_col4, #T_8da40_row0_col5, #T_8da40_row0_col6, #T_8da40_row0_col7, #T_8da40_row0_col8, #T_8da40_row0_col9, #T_8da40_row0_col10, #T_8da40_row0_col11, #T_8da40_row0_col12, #T_8da40_row0_col13, #T_8da40_row0_col14, #T_8da40_row0_col15, #T_8da40_row0_col16, #T_8da40_row0_col17, #T_8da40_row0_col18, #T_8da40_row0_col19, #T_8da40_row0_col20, #T_8da40_row0_col21, #T_8da40_row0_col22, #T_8da40_row0_col23, #T_8da40_row0_col24, #T_8da40_row0_col25, #T_8da40_row0_col26, #T_8da40_row0_col27, #T_8da40_row0_col28 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_8da40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8da40_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_8da40_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_8da40_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_8da40_level0_col3" class="col_heading level0 col3" >Marital_Status</th>
#       <th id="T_8da40_level0_col4" class="col_heading level0 col4" >Income</th>
#       <th id="T_8da40_level0_col5" class="col_heading level0 col5" >Kidhome</th>
#       <th id="T_8da40_level0_col6" class="col_heading level0 col6" >Teenhome</th>
#       <th id="T_8da40_level0_col7" class="col_heading level0 col7" >Dt_Customer</th>
#       <th id="T_8da40_level0_col8" class="col_heading level0 col8" >Recency</th>
#       <th id="T_8da40_level0_col9" class="col_heading level0 col9" >MntWines</th>
#       <th id="T_8da40_level0_col10" class="col_heading level0 col10" >MntFruits</th>
#       <th id="T_8da40_level0_col11" class="col_heading level0 col11" >MntMeatProducts</th>
#       <th id="T_8da40_level0_col12" class="col_heading level0 col12" >MntFishProducts</th>
#       <th id="T_8da40_level0_col13" class="col_heading level0 col13" >MntSweetProducts</th>
#       <th id="T_8da40_level0_col14" class="col_heading level0 col14" >MntGoldProds</th>
#       <th id="T_8da40_level0_col15" class="col_heading level0 col15" >NumDealsPurchases</th>
#       <th id="T_8da40_level0_col16" class="col_heading level0 col16" >NumWebPurchases</th>
#       <th id="T_8da40_level0_col17" class="col_heading level0 col17" >NumCatalogPurchases</th>
#       <th id="T_8da40_level0_col18" class="col_heading level0 col18" >NumStorePurchases</th>
#       <th id="T_8da40_level0_col19" class="col_heading level0 col19" >NumWebVisitsMonth</th>
#       <th id="T_8da40_level0_col20" class="col_heading level0 col20" >AcceptedCmp3</th>
#       <th id="T_8da40_level0_col21" class="col_heading level0 col21" >AcceptedCmp4</th>
#       <th id="T_8da40_level0_col22" class="col_heading level0 col22" >AcceptedCmp5</th>
#       <th id="T_8da40_level0_col23" class="col_heading level0 col23" >AcceptedCmp1</th>
#       <th id="T_8da40_level0_col24" class="col_heading level0 col24" >AcceptedCmp2</th>
#       <th id="T_8da40_level0_col25" class="col_heading level0 col25" >Complain</th>
#       <th id="T_8da40_level0_col26" class="col_heading level0 col26" >Z_CostContact</th>
#       <th id="T_8da40_level0_col27" class="col_heading level0 col27" >Z_Revenue</th>
#       <th id="T_8da40_level0_col28" class="col_heading level0 col28" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8da40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8da40_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_8da40_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_8da40_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_8da40_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8da40_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8da40_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_8da40_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_8da40_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_8da40_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_8da40_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_8da40_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_8da40_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_8da40_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_8da40_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_8da40_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_8da40_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_8da40_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_8da40_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_8da40_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_8da40_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_8da40_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_8da40_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_8da40_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_8da40_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_8da40_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_8da40_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_8da40_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_8da40_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_8da40_row0_col28" class="data row0 col28" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
data["Dt_Customer"] = pd.to_datetime(data["Dt_Customer"], dayfirst=True)
dates = []
for i in data["Dt_Customer"]:
    i = i.date()
    dates.append(i)

print(f"Newest customer's enrollment date is {max(dates)}")
print(f"Oldest customer's enrollment date is {min(dates)}")
# Out:
# Newest customer's enrollment date is 2014-06-29
# Oldest customer's enrollment date is 2012-07-30

# %%
days = []
newest = max(dates)
for i in dates:
    duration = newest - i
    days.append(duration)
data["Customer Loyalty"] = days
data["Customer Loyalty"] = data["Customer Loyalty"].dt.days
data["Age"] = 2025 - data["Year_Birth"]
data["Spent"] = data["MntWines"] + data["MntFruits"] + data["MntMeatProducts"] + data["MntFishProducts"] + data["MntSweetProducts"] + data["MntGoldProds"]
data["Children"] = data["Kidhome"] + data["Teenhome"]
data["Parental Status"] = np.where(data["Children"] > 0, 1, 0)
data["Marital_Status"].replace({"Married": "Couple", "Together": "Couple", "Absurd": "Alone", "Widow": "Alone", "YOLO": "Alone", "Divorced": "Alone", "Single": "Alone"}, inplace=True)
data["Education"].replace({"Basic": "Undergraduate", "2n Cycle": "Undergraduate", "Graduation": "Graduate", "Master": "Postgraduate", "PhD": "Postgraduate"}, inplace=True)
data["Total Promo"] = data["AcceptedCmp1"] + data["AcceptedCmp2"] + data["AcceptedCmp3"] + data["AcceptedCmp4"] + data["AcceptedCmp5"]
data.rename(columns={"Marital_Status": "Marital Status", "MntWines": "Wines", "MntFruits": "Fruits", "MntMeatProducts": "Meat", "MntFishProducts": "Fish", "MntSweetProducts": "Sweets", "MntGoldProds": "Gold", "NumWebPurchases": "Web", "NumCatalogPurchases": "Catalog", "NumStorePurchases": "Store", "NumDealsPurchases": "Discount Purchases"}, inplace=True)
data = data[["ID", "Age", "Education", "Marital Status", "Parental Status", "Children", "Kidhome", "Teenhome", "Income", "Spent", "Customer Loyalty", "Recency", "Wines", "Fruits", "Meat", "Fish", "Sweets", "Gold", "Web", "Catalog", "Store", "Discount Purchases", "Total Promo", "NumWebVisitsMonth"]]

data = data[data["Age"] < 90]
data = data[data["Income"] < 600000]

# %%
print(f"After preprocessing, let's have a glimpse of the final dataset:")
data.head().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After preprocessing, let's have a glimpse of the final dataset:
# <style type="text/css">
# #T_49c86_row0_col0, #T_49c86_row0_col1, #T_49c86_row0_col2, #T_49c86_row0_col3, #T_49c86_row0_col4, #T_49c86_row0_col5, #T_49c86_row0_col6, #T_49c86_row0_col7, #T_49c86_row0_col8, #T_49c86_row0_col9, #T_49c86_row0_col10, #T_49c86_row0_col11, #T_49c86_row0_col12, #T_49c86_row0_col13, #T_49c86_row0_col14, #T_49c86_row0_col15, #T_49c86_row0_col16, #T_49c86_row0_col17, #T_49c86_row0_col18, #T_49c86_row0_col19, #T_49c86_row0_col20, #T_49c86_row0_col21, #T_49c86_row0_col22, #T_49c86_row0_col23, #T_49c86_row1_col0, #T_49c86_row1_col1, #T_49c86_row1_col2, #T_49c86_row1_col3, #T_49c86_row1_col4, #T_49c86_row1_col5, #T_49c86_row1_col6, #T_49c86_row1_col7, #T_49c86_row1_col8, #T_49c86_row1_col9, #T_49c86_row1_col10, #T_49c86_row1_col11, #T_49c86_row1_col12, #T_49c86_row1_col13, #T_49c86_row1_col14, #T_49c86_row1_col15, #T_49c86_row1_col16, #T_49c86_row1_col17, #T_49c86_row1_col18, #T_49c86_row1_col19, #T_49c86_row1_col20, #T_49c86_row1_col21, #T_49c86_row1_col22, #T_49c86_row1_col23, #T_49c86_row2_col0, #T_49c86_row2_col1, #T_49c86_row2_col2, #T_49c86_row2_col3, #T_49c86_row2_col4, #T_49c86_row2_col5, #T_49c86_row2_col6, #T_49c86_row2_col7, #T_49c86_row2_col8, #T_49c86_row2_col9, #T_49c86_row2_col10, #T_49c86_row2_col11, #T_49c86_row2_col12, #T_49c86_row2_col13, #T_49c86_row2_col14, #T_49c86_row2_col15, #T_49c86_row2_col16, #T_49c86_row2_col17, #T_49c86_row2_col18, #T_49c86_row2_col19, #T_49c86_row2_col20, #T_49c86_row2_col21, #T_49c86_row2_col22, #T_49c86_row2_col23, #T_49c86_row3_col0, #T_49c86_row3_col1, #T_49c86_row3_col2, #T_49c86_row3_col3, #T_49c86_row3_col4, #T_49c86_row3_col5, #T_49c86_row3_col6, #T_49c86_row3_col7, #T_49c86_row3_col8, #T_49c86_row3_col9, #T_49c86_row3_col10, #T_49c86_row3_col11, #T_49c86_row3_col12, #T_49c86_row3_col13, #T_49c86_row3_col14, #T_49c86_row3_col15, #T_49c86_row3_col16, #T_49c86_row3_col17, #T_49c86_row3_col18, #T_49c86_row3_col19, #T_49c86_row3_col20, #T_49c86_row3_col21, #T_49c86_row3_col22, #T_49c86_row3_col23, #T_49c86_row4_col0, #T_49c86_row4_col1, #T_49c86_row4_col2, #T_49c86_row4_col3, #T_49c86_row4_col4, #T_49c86_row4_col5, #T_49c86_row4_col6, #T_49c86_row4_col7, #T_49c86_row4_col8, #T_49c86_row4_col9, #T_49c86_row4_col10, #T_49c86_row4_col11, #T_49c86_row4_col12, #T_49c86_row4_col13, #T_49c86_row4_col14, #T_49c86_row4_col15, #T_49c86_row4_col16, #T_49c86_row4_col17, #T_49c86_row4_col18, #T_49c86_row4_col19, #T_49c86_row4_col20, #T_49c86_row4_col21, #T_49c86_row4_col22, #T_49c86_row4_col23 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_49c86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49c86_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_49c86_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_49c86_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_49c86_level0_col3" class="col_heading level0 col3" >Marital Status</th>
#       <th id="T_49c86_level0_col4" class="col_heading level0 col4" >Parental Status</th>
#       <th id="T_49c86_level0_col5" class="col_heading level0 col5" >Children</th>
#       <th id="T_49c86_level0_col6" class="col_heading level0 col6" >Kidhome</th>
#       <th id="T_49c86_level0_col7" class="col_heading level0 col7" >Teenhome</th>
#       <th id="T_49c86_level0_col8" class="col_heading level0 col8" >Income</th>
#       <th id="T_49c86_level0_col9" class="col_heading level0 col9" >Spent</th>
#       <th id="T_49c86_level0_col10" class="col_heading level0 col10" >Customer Loyalty</th>
#       <th id="T_49c86_level0_col11" class="col_heading level0 col11" >Recency</th>
#       <th id="T_49c86_level0_col12" class="col_heading level0 col12" >Wines</th>
#       <th id="T_49c86_level0_col13" class="col_heading level0 col13" >Fruits</th>
#       <th id="T_49c86_level0_col14" class="col_heading level0 col14" >Meat</th>
#       <th id="T_49c86_level0_col15" class="col_heading level0 col15" >Fish</th>
#       <th id="T_49c86_level0_col16" class="col_heading level0 col16" >Sweets</th>
#       <th id="T_49c86_level0_col17" class="col_heading level0 col17" >Gold</th>
#       <th id="T_49c86_level0_col18" class="col_heading level0 col18" >Web</th>
#       <th id="T_49c86_level0_col19" class="col_heading level0 col19" >Catalog</th>
#       <th id="T_49c86_level0_col20" class="col_heading level0 col20" >Store</th>
#       <th id="T_49c86_level0_col21" class="col_heading level0 col21" >Discount Purchases</th>
#       <th id="T_49c86_level0_col22" class="col_heading level0 col22" >Total Promo</th>
#       <th id="T_49c86_level0_col23" class="col_heading level0 col23" >NumWebVisitsMonth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49c86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49c86_row0_col0" class="data row0 col0" >5524</td>
#       <td id="T_49c86_row0_col1" class="data row0 col1" >68</td>
#       <td id="T_49c86_row0_col2" class="data row0 col2" >Graduate</td>
#       <td id="T_49c86_row0_col3" class="data row0 col3" >Alone</td>
#       <td id="T_49c86_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_49c86_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_49c86_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_49c86_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_49c86_row0_col8" class="data row0 col8" >58138.000000</td>
#       <td id="T_49c86_row0_col9" class="data row0 col9" >1617</td>
#       <td id="T_49c86_row0_col10" class="data row0 col10" >663</td>
#       <td id="T_49c86_row0_col11" class="data row0 col11" >58</td>
#       <td id="T_49c86_row0_col12" class="data row0 col12" >635</td>
#       <td id="T_49c86_row0_col13" class="data row0 col13" >88</td>
#       <td id="T_49c86_row0_col14" class="data row0 col14" >546</td>
#       <td id="T_49c86_row0_col15" class="data row0 col15" >172</td>
#       <td id="T_49c86_row0_col16" class="data row0 col16" >88</td>
#       <td id="T_49c86_row0_col17" class="data row0 col17" >88</td>
#       <td id="T_49c86_row0_col18" class="data row0 col18" >8</td>
#       <td id="T_49c86_row0_col19" class="data row0 col19" >10</td>
#       <td id="T_49c86_row0_col20" class="data row0 col20" >4</td>
#       <td id="T_49c86_row0_col21" class="data row0 col21" >3</td>
#       <td id="T_49c86_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_49c86_row0_col23" class="data row0 col23" >7</td>
#     </tr>
#     <tr>
#       <th id="T_49c86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49c86_row1_col0" class="data row1 col0" >2174</td>
#       <td id="T_49c86_row1_col1" class="data row1 col1" >71</td>
#       <td id="T_49c86_row1_col2" class="data row1 col2" >Graduate</td>
#       <td id="T_49c86_row1_col3" class="data row1 col3" >Alone</td>
#       <td id="T_49c86_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_49c86_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_49c86_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_49c86_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_49c86_row1_col8" class="data row1 col8" >46344.000000</td>
#       <td id="T_49c86_row1_col9" class="data row1 col9" >27</td>
#       <td id="T_49c86_row1_col10" class="data row1 col10" >113</td>
#       <td id="T_49c86_row1_col11" class="data row1 col11" >38</td>
#       <td id="T_49c86_row1_col12" class="data row1 col12" >11</td>
#       <td id="T_49c86_row1_col13" class="data row1 col13" >1</td>
#       <td id="T_49c86_row1_col14" class="data row1 col14" >6</td>
#       <td id="T_49c86_row1_col15" class="data row1 col15" >2</td>
#       <td id="T_49c86_row1_col16" class="data row1 col16" >1</td>
#       <td id="T_49c86_row1_col17" class="data row1 col17" >6</td>
#       <td id="T_49c86_row1_col18" class="data row1 col18" >1</td>
#       <td id="T_49c86_row1_col19" class="data row1 col19" >1</td>
#       <td id="T_49c86_row1_col20" class="data row1 col20" >2</td>
#       <td id="T_49c86_row1_col21" class="data row1 col21" >2</td>
#       <td id="T_49c86_row1_col22" class="data row1 col22" >0</

# %%
print(f"After preprocessing, let's have a look on the summary of the dataset:")
data.describe().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After preprocessing, let's have a look on the summary of the dataset:
# <style type="text/css">
# #T_b53e0_row0_col0, #T_b53e0_row0_col1, #T_b53e0_row0_col2, #T_b53e0_row0_col3, #T_b53e0_row0_col4, #T_b53e0_row0_col5, #T_b53e0_row0_col6, #T_b53e0_row0_col7, #T_b53e0_row0_col8, #T_b53e0_row0_col9, #T_b53e0_row0_col10, #T_b53e0_row0_col11, #T_b53e0_row0_col12, #T_b53e0_row0_col13, #T_b53e0_row0_col14, #T_b53e0_row0_col15, #T_b53e0_row0_col16, #T_b53e0_row0_col17, #T_b53e0_row0_col18, #T_b53e0_row0_col19, #T_b53e0_row0_col20, #T_b53e0_row0_col21, #T_b53e0_row1_col0, #T_b53e0_row1_col1, #T_b53e0_row1_col2, #T_b53e0_row1_col3, #T_b53e0_row1_col4, #T_b53e0_row1_col5, #T_b53e0_row1_col6, #T_b53e0_row1_col7, #T_b53e0_row1_col8, #T_b53e0_row1_col9, #T_b53e0_row1_col10, #T_b53e0_row1_col11, #T_b53e0_row1_col12, #T_b53e0_row1_col13, #T_b53e0_row1_col14, #T_b53e0_row1_col15, #T_b53e0_row1_col16, #T_b53e0_row1_col17, #T_b53e0_row1_col18, #T_b53e0_row1_col19, #T_b53e0_row1_col20, #T_b53e0_row1_col21, #T_b53e0_row2_col0, #T_b53e0_row2_col1, #T_b53e0_row2_col2, #T_b53e0_row2_col3, #T_b53e0_row2_col4, #T_b53e0_row2_col5, #T_b53e0_row2_col6, #T_b53e0_row2_col7, #T_b53e0_row2_col8, #T_b53e0_row2_col9, #T_b53e0_row2_col10, #T_b53e0_row2_col11, #T_b53e0_row2_col12, #T_b53e0_row2_col13, #T_b53e0_row2_col14, #T_b53e0_row2_col15, #T_b53e0_row2_col16, #T_b53e0_row2_col17, #T_b53e0_row2_col18, #T_b53e0_row2_col19, #T_b53e0_row2_col20, #T_b53e0_row2_col21, #T_b53e0_row3_col0, #T_b53e0_row3_col1, #T_b53e0_row3_col2, #T_b53e0_row3_col3, #T_b53e0_row3_col4, #T_b53e0_row3_col5, #T_b53e0_row3_col6, #T_b53e0_row3_col7, #T_b53e0_row3_col8, #T_b53e0_row3_col9, #T_b53e0_row3_col10, #T_b53e0_row3_col11, #T_b53e0_row3_col12, #T_b53e0_row3_col13, #T_b53e0_row3_col14, #T_b53e0_row3_col15, #T_b53e0_row3_col16, #T_b53e0_row3_col17, #T_b53e0_row3_col18, #T_b53e0_row3_col19, #T_b53e0_row3_col20, #T_b53e0_row3_col21, #T_b53e0_row4_col0, #T_b53e0_row4_col1, #T_b53e0_row4_col2, #T_b53e0_row4_col3, #T_b53e0_row4_col4, #T_b53e0_row4_col5, #T_b53e0_row4_col6, #T_b53e0_row4_col7, #T_b53e0_row4_col8, #T_b53e0_row4_col9, #T_b53e0_row4_col10, #T_b53e0_row4_col11, #T_b53e0_row4_col12, #T_b53e0_row4_col13, #T_b53e0_row4_col14, #T_b53e0_row4_col15, #T_b53e0_row4_col16, #T_b53e0_row4_col17, #T_b53e0_row4_col18, #T_b53e0_row4_col19, #T_b53e0_row4_col20, #T_b53e0_row4_col21, #T_b53e0_row5_col0, #T_b53e0_row5_col1, #T_b53e0_row5_col2, #T_b53e0_row5_col3, #T_b53e0_row5_col4, #T_b53e0_row5_col5, #T_b53e0_row5_col6, #T_b53e0_row5_col7, #T_b53e0_row5_col8, #T_b53e0_row5_col9, #T_b53e0_row5_col10, #T_b53e0_row5_col11, #T_b53e0_row5_col12, #T_b53e0_row5_col13, #T_b53e0_row5_col14, #T_b53e0_row5_col15, #T_b53e0_row5_col16, #T_b53e0_row5_col17, #T_b53e0_row5_col18, #T_b53e0_row5_col19, #T_b53e0_row5_col20, #T_b53e0_row5_col21, #T_b53e0_row6_col0, #T_b53e0_row6_col1, #T_b53e0_row6_col2, #T_b53e0_row6_col3, #T_b53e0_row6_col4, #T_b53e0_row6_col5, #T_b53e0_row6_col6, #T_b53e0_row6_col7, #T_b53e0_row6_col8, #T_b53e0_row6_col9, #T_b53e0_row6_col10, #T_b53e0_row6_col11, #T_b53e0_row6_col12, #T_b53e0_row6_col13, #T_b53e0_row6_col14, #T_b53e0_row6_col15, #T_b53e0_row6_col16, #T_b53e0_row6_col17, #T_b53e0_row6_col18, #T_b53e0_row6_col19, #T_b53e0_row6_col20, #T_b53e0_row6_col21, #T_b53e0_row7_col0, #T_b53e0_row7_col1, #T_b53e0_row7_col2, #T_b53e0_row7_col3, #T_b53e0_row7_col4, #T_b53e0_row7_col5, #T_b53e0_row7_col6, #T_b53e0_row7_col7, #T_b53e0_row7_col8, #T_b53e0_row7_col9, #T_b53e0_row7_col10, #T_b53e0_row7_col11, #T_b53e0_row7_col12, #T_b53e0_row7_col13, #T_b53e0_row7_col14, #T_b53e0_row7_col15, #T_b53e0_row7_col16, #T_b53e0_row7_col17, #T_b53e0_row7_col18, #T_b53e0_row7_col19, #T_b53e0_row7_col20, #T_b53e0_row7_col21 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_b53e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b53e0_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_b53e0_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_b53e0_level0_col2" class="col_heading level0 col2" >Parental Status</th>
#       <th id="T_b53e0_level0_col3" class="col_heading level0 col3" >Children</th>
#       <th id="T_b53e0_level0_col4" class="col_heading level0 col4" >Kidhome</th>
#       <th id="T_b53e0_level0_col5" class="col_heading level0 col5" >Teenhome</th>
#       <th id="T_b53e0_level0_col6" class="col_heading level0 col6" >Income</th>
#       <th id="T_b53e0_level0_col7" class="col_heading level0 col7" >Spent</th>
#       <th id="T_b53e0_level0_col8" class="col_heading level0 col8" >Customer Loyalty</th>
#       <th id="T_b53e0_level0_col9" class="col_heading level0 col9" >Recency</th>
#       <th id="T_b53e0_level0_col10" class="col_heading level0 col10" >Wines</th>
#       <th id="T_b53e0_level0_col11" class="col_heading level0 col11" >Fruits</th>
#       <th id="T_b53e0_level0_col12" class="col_heading level0 col12" >Meat</th>
#       <th id="T_b53e0_level0_col13" class="col_heading level0 col13" >Fish</th>
#       <th id="T_b53e0_level0_col14" class="col_heading level0 col14" >Sweets</th>
#       <th id="T_b53e0_level0_col15" class="col_heading level0 col15" >Gold</th>
#       <th id="T_b53e0_level0_col16" class="col_heading level0 col16" >Web</th>
#       <th id="T_b53e0_level0_col17" class="col_heading level0 col17" >Catalog</th>
#       <th id="T_b53e0_level0_col18" class="col_heading level0 col18" >Store</th>
#       <th id="T_b53e0_level0_col19" class="col_heading level0 col19" >Discount Purchases</th>
#       <th id="T_b53e0_level0_col20" class="col_heading level0 col20" >Total Promo</th>
#       <th id="T_b53e0_level0_col21" class="col_heading level0 col21" >NumWebVisitsMonth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b53e0_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_b53e0_row0_col0" class="data row0 col0" >2212.000000</td>
#       <td id="T_b53e0_row0_col1" class="data row0 col1" >2212.000000</td>
#       <td id="T_b53e0_row0_col2" class="data row0 col2" >2212.000000</td>
#       <td id="T_b53e0_row0_col3" class="data row0 col3" >2212.000000</td>
#       <td id="T_b53e0_row0_col4" class="data row0 col4" >2212.000000</td>
#       <td id="T_b53e0_row0_col5" class="data row0 col5" >2212.000000</td>
#       <td id="T_b53e0_row0_col6" class="data row0 col6" >2212.000000</td>
#       <td id="T_b53e0_row0_col7" class="data row0 col7" >2212.000000</td>
#       <td id="T_b53e0_row0_col8" class="data row0 col8" >2212.000000</td>
#       <td id="T_b53e0_row0_col9" class="data row0 col9" >2212.000000</td>
#       <td id="T_b53e0_row0_col10" class="data row0 col10" >2212.000000</td>
#       <td id="T_b53e0_row0_col11" class="data row0 col11" >2212.000000</td>
#       <td id="T_b53e0_row0_col12" class="data row0 col12" >2212.000000</td>
#       <td id="T_b53e0_row0_col13" class="data row0 col13" >2212.000000</td>
#       <td id="T_b53e0_row0_col14" class="data row0 col14" >2212.000000</td>
#       <td id="T_b53e0_row0_col15" class="data row0 col15" >2212.000000</td>
#       <td id="T_b53e0_row0_col16" class="data row0 col16" >2212.000000</td>
#       <td id="T_b53e0_row0_col17" class="data row0 col17" >2212.000000</td>
#       <td id="T_b53e0_row0_col18" class="data row0 col18" >2212.000000</td>
#       <td id="T_b53e0_row0_col19" class="data row0 col19" >2212.000000</td>
#       <td id="T_b53e0_row0_col20" class="data row0 col20" >2212.000000</td>
#       <td id="T_b53e0_row0_col21" class="data row0 col21" >2212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53e0_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_b53e0_row1_col0" class="data row1 col0" >5585.160940</td>
#       <td id="T_b53e0_row1_col1" class="data row1 col1" >56.086347</td>
#       <td id="T_b53e0_row1_col2" class="data row1 col2" >0.714286</td>
#       <td id="T_b53e0_row1_col3" class="data row1 col3" >0.947559</td>
#       <td id="T_b53e0_row1_col4" class="data row1 col4" >0.441682</td>
#       <td id="T_b53e0_row1_col5" class="data row1 col5" >0.505877</td>
#       <td id="T_b53e0_row1_col6" class="data row1 col6" >51958.810579</

# %%
data.describe(include=object).T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_4543c_row0_col0, #T_4543c_row0_col1, #T_4543c_row0_col2, #T_4543c_row0_col3, #T_4543c_row1_col0, #T_4543c_row1_col1, #T_4543c_row1_col2, #T_4543c_row1_col3 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_4543c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4543c_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_4543c_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_4543c_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_4543c_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4543c_level0_row0" class="row_heading level0 row0" >Education</th>
#       <td id="T_4543c_row0_col0" class="data row0 col0" >2212</td>
#       <td id="T_4543c_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_4543c_row0_col2" class="data row0 col2" >Graduate</td>
#       <td id="T_4543c_row0_col3" class="data row0 col3" >1115</td>
#     </tr>
#     <tr>
#       <th id="T_4543c_level0_row1" class="row_heading level0 row1" >Marital Status</th>
#       <td id="T_4543c_row1_col0" class="data row1 col0" >2212</td>
#       <td id="T_4543c_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_4543c_row1_col2" class="data row1 col2" >Couple</td>
#       <td id="T_4543c_row1_col3" class="data row1 col3" >1428</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **4. Custom palette**

# %%
sns.set_style("white")
sns.set(rc={"axes.facecolor": "#d4c8ba", "figure.facecolor": "#d4c8ba"})
sns.set_context("poster", font_scale=.7)

palette = ["#101B15","#3A392B","#7A7D58","#FFF7B6","#DD9954","#94583C","#601600"]
palette_cmap = ["#B9C0C9","#D6B2B1","#F3AB60","#9F8A78","#9E726F","#682F2F"]
cluster = ["#B9C0C9","#682F2F","#7A7D58","#DD9954"]
