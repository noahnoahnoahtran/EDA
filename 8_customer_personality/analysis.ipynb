# %% [markdown]
# # **1. Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering
from yellowbrick.cluster import KElbowVisualizer

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **2. Load dataset**

# %%
data = pd.read_csv("./datasets/marketing_campaign.csv", sep="\t")

# %% [markdown]
# # **3. Basic exploration**

# %%
print(f"Shape of the dataset: {data.shape}")
print(f"\nGlimpse of the dataset:")
data.head().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Shape of the dataset: (2240, 29)
#
# Glimpse of the dataset:
# <style type="text/css">
# #T_090af_row0_col0, #T_090af_row0_col1, #T_090af_row0_col2, #T_090af_row0_col3, #T_090af_row0_col4, #T_090af_row0_col5, #T_090af_row0_col6, #T_090af_row0_col7, #T_090af_row0_col8, #T_090af_row0_col9, #T_090af_row0_col10, #T_090af_row0_col11, #T_090af_row0_col12, #T_090af_row0_col13, #T_090af_row0_col14, #T_090af_row0_col15, #T_090af_row0_col16, #T_090af_row0_col17, #T_090af_row0_col18, #T_090af_row0_col19, #T_090af_row0_col20, #T_090af_row0_col21, #T_090af_row0_col22, #T_090af_row0_col23, #T_090af_row0_col24, #T_090af_row0_col25, #T_090af_row0_col26, #T_090af_row0_col27, #T_090af_row0_col28, #T_090af_row1_col0, #T_090af_row1_col1, #T_090af_row1_col2, #T_090af_row1_col3, #T_090af_row1_col4, #T_090af_row1_col5, #T_090af_row1_col6, #T_090af_row1_col7, #T_090af_row1_col8, #T_090af_row1_col9, #T_090af_row1_col10, #T_090af_row1_col11, #T_090af_row1_col12, #T_090af_row1_col13, #T_090af_row1_col14, #T_090af_row1_col15, #T_090af_row1_col16, #T_090af_row1_col17, #T_090af_row1_col18, #T_090af_row1_col19, #T_090af_row1_col20, #T_090af_row1_col21, #T_090af_row1_col22, #T_090af_row1_col23, #T_090af_row1_col24, #T_090af_row1_col25, #T_090af_row1_col26, #T_090af_row1_col27, #T_090af_row1_col28, #T_090af_row2_col0, #T_090af_row2_col1, #T_090af_row2_col2, #T_090af_row2_col3, #T_090af_row2_col4, #T_090af_row2_col5, #T_090af_row2_col6, #T_090af_row2_col7, #T_090af_row2_col8, #T_090af_row2_col9, #T_090af_row2_col10, #T_090af_row2_col11, #T_090af_row2_col12, #T_090af_row2_col13, #T_090af_row2_col14, #T_090af_row2_col15, #T_090af_row2_col16, #T_090af_row2_col17, #T_090af_row2_col18, #T_090af_row2_col19, #T_090af_row2_col20, #T_090af_row2_col21, #T_090af_row2_col22, #T_090af_row2_col23, #T_090af_row2_col24, #T_090af_row2_col25, #T_090af_row2_col26, #T_090af_row2_col27, #T_090af_row2_col28, #T_090af_row3_col0, #T_090af_row3_col1, #T_090af_row3_col2, #T_090af_row3_col3, #T_090af_row3_col4, #T_090af_row3_col5, #T_090af_row3_col6, #T_090af_row3_col7, #T_090af_row3_col8, #T_090af_row3_col9, #T_090af_row3_col10, #T_090af_row3_col11, #T_090af_row3_col12, #T_090af_row3_col13, #T_090af_row3_col14, #T_090af_row3_col15, #T_090af_row3_col16, #T_090af_row3_col17, #T_090af_row3_col18, #T_090af_row3_col19, #T_090af_row3_col20, #T_090af_row3_col21, #T_090af_row3_col22, #T_090af_row3_col23, #T_090af_row3_col24, #T_090af_row3_col25, #T_090af_row3_col26, #T_090af_row3_col27, #T_090af_row3_col28, #T_090af_row4_col0, #T_090af_row4_col1, #T_090af_row4_col2, #T_090af_row4_col3, #T_090af_row4_col4, #T_090af_row4_col5, #T_090af_row4_col6, #T_090af_row4_col7, #T_090af_row4_col8, #T_090af_row4_col9, #T_090af_row4_col10, #T_090af_row4_col11, #T_090af_row4_col12, #T_090af_row4_col13, #T_090af_row4_col14, #T_090af_row4_col15, #T_090af_row4_col16, #T_090af_row4_col17, #T_090af_row4_col18, #T_090af_row4_col19, #T_090af_row4_col20, #T_090af_row4_col21, #T_090af_row4_col22, #T_090af_row4_col23, #T_090af_row4_col24, #T_090af_row4_col25, #T_090af_row4_col26, #T_090af_row4_col27, #T_090af_row4_col28 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_090af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_090af_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_090af_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_090af_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_090af_level0_col3" class="col_heading level0 col3" >Marital_Status</th>
#       <th id="T_090af_level0_col4" class="col_heading level0 col4" >Income</th>
#       <th id="T_090af_level0_col5" class="col_heading level0 col5" >Kidhome</th>
#       <th id="T_090af_level0_col6" class="col_heading level0 col6" >Teenhome</th>
#       <th id="T_090af_level0_col7" class="col_heading level0 col7" >Dt_Customer</th>
#       <th id="T_090af_level0_col8" class="col_heading level0 col8" >Recency</th>
#       <th id="T_090af_level0_col9" class="col_heading level0 col9" >MntWines</th>
#       <th id="T_090af_level0_col10" class="col_heading level0 col10" >MntFruits</th>
#       <th id="T_090af_level0_col11" class="col_heading level0 col11" >MntMeatProducts</th>
#       <th id="T_090af_level0_col12" class="col_heading level0 col12" >MntFishProducts</th>
#       <th id="T_090af_level0_col13" class="col_heading level0 col13" >MntSweetProducts</th>
#       <th id="T_090af_level0_col14" class="col_heading level0 col14" >MntGoldProds</th>
#       <th id="T_090af_level0_col15" class="col_heading level0 col15" >NumDealsPurchases</th>
#       <th id="T_090af_level0_col16" class="col_heading level0 col16" >NumWebPurchases</th>
#       <th id="T_090af_level0_col17" class="col_heading level0 col17" >NumCatalogPurchases</th>
#       <th id="T_090af_level0_col18" class="col_heading level0 col18" >NumStorePurchases</th>
#       <th id="T_090af_level0_col19" class="col_heading level0 col19" >NumWebVisitsMonth</th>
#       <th id="T_090af_level0_col20" class="col_heading level0 col20" >AcceptedCmp3</th>
#       <th id="T_090af_level0_col21" class="col_heading level0 col21" >AcceptedCmp4</th>
#       <th id="T_090af_level0_col22" class="col_heading level0 col22" >AcceptedCmp5</th>
#       <th id="T_090af_level0_col23" class="col_heading level0 col23" >AcceptedCmp1</th>
#       <th id="T_090af_level0_col24" class="col_heading level0 col24" >AcceptedCmp2</th>
#       <th id="T_090af_level0_col25" class="col_heading level0 col25" >Complain</th>
#       <th id="T_090af_level0_col26" class="col_heading level0 col26" >Z_CostContact</th>
#       <th id="T_090af_level0_col27" class="col_heading level0 col27" >Z_Revenue</th>
#       <th id="T_090af_level0_col28" class="col_heading level0 col28" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_090af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_090af_row0_col0" class="data row0 col0" >5524</td>
#       <td id="T_090af_row0_col1" class="data row0 col1" >1957</td>
#       <td id="T_090af_row0_col2" class="data row0 col2" >Graduation</td>
#       <td id="T_090af_row0_col3" class="data row0 col3" >Single</td>
#       <td id="T_090af_row0_col4" class="data row0 col4" >58138.000000</td>
#       <td id="T_090af_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_090af_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_090af_row0_col7" class="data row0 col7" >04-09-2012</td>
#       <td id="T_090af_row0_col8" class="data row0 col8" >58</td>
#       <td id="T_090af_row0_col9" class="data row0 col9" >635</td>
#       <td id="T_090af_row0_col10" class="data row0 col10" >88</td>
#       <td id="T_090af_row0_col11" class="data row0 col11" >546</td>
#       <td id="T_090af_row0_col12" class="data row0 col12" >172</td>
#       <td id="T_090af_row0_col13" class="data row0 col13" >88</td>
#       <td id="T_090af_row0_col14" class="data row0 col14" >88</td>
#       <td id="T_090af_row0_col15" class="data row0 col15" >3</td>
#       <td id="T_090af_row0_col16" class="data row0 col16" >8</td>
#       <td id="T_090af_row0_col17" class="data row0 col17" >10</td>
#       <td id="T_090af_row0_col18" class="data row0 col18" >4</td>
#       <td id="T_090af_row0_col19" class="data row0 col19" >7</td>
#       <td id="T_090af_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_090af_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_090af_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_090af_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_090af_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_090af_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_090af_row0_col26" class="data row0 col26" >3</td>
#       <td id="T_090af_row0_col27" class="data row0 col27" >11</td>
#       <td id="T_090af_row0_col28" class="data row0 col28" >1</td>
#     </tr>
#     <tr>
#       <th id="T_090af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_090af_row1_col0" class="data row1 col0" >2174</td>
#       <td id="T_090af_row1_col1" class="data row1 col1" >1954</td>

# %%
print(f"Information of the dataset:\n")
print(data.info())
# Out:
# Information of the dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  AcceptedCmp3         2240 non-null   int64
#  21  AcceptedCmp4         2240 non-null   int64
#  22  AcceptedCmp5         2240 non-null   int64
#  23  AcceptedCmp1         2240 non-null   int64
#  24  AcceptedCmp2         2240 non-null   int64
#  25  Complain             2240 non-null   int64
#  26  Z_CostContact        2240 non-null   int64
#  27  Z_Revenue            2240 non-null   int64
#  28  Response             2240 non-null   int64
# dtypes: float64(1), int64(25), object(3)
# memory usage: 507.6+ KB
# None
